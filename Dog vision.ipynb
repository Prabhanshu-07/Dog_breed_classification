# %%
import  tensorflow as tf
print("Tf version:", tf.__version__)

import itertools
# Out:
# Tf version: 2.3.0

# %%
import tensorflow_hub as hub
print("Hub version:", hub.__version__)
# Out:
# Hub version: 0.12.0

# %%
# Checkout the labels of our data
import pandas as pd
labels_csv=pd.read_csv("labels.csv")
print(labels_csv.describe())
print(labels_csv.head())
# Out:
#                                       id               breed
# count                              10222               10222
# unique                             10222                 120
# top     ac2e27fa8891e1d7a2ee88196a2a4223  scottish_deerhound
# freq                                   1                 126
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
labels_csv.shape
# Out:
# (10222, 2)

# %%
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
from IPython.display import Image

# %%
# Checking given labels
labels_using=['beagle', 'chihuahua', 'doberman', 'french_bulldog', 'golden_retriever', 'malamute', 'pug',
              'saint_bernard', 'scottish_deerhound', 'tibetan_mastiff']

# %%
labels_csv.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
for index,breed in labels_csv.iterrows():
    if breed[1] not in labels_using:
        labels_csv=labels_csv.drop([index])
labels_csv.shape
# Out:
# (841, 2)

# %%
# Create pathnames from image ID's
filenames=["train/"+fname +".jpg"for fname in labels_csv["id"]]
filenames[:10]
# Out:
# ['train/0021f9ceb3235effd7fcde7f7538ed62.jpg',
#  'train/0042188c895a2f14ef64a918ed9c7b64.jpg',
#  'train/008b1271ed1addaccf93783b39deab45.jpg',
#  'train/00a366d4b4a9bbb6c8a63126697b7656.jpg',
#  'train/0100f55e4f0fe28f2c0465d3fc4b9897.jpg',
#  'train/01e787576c003930f96c966f9c3e1d44.jpg',
#  'train/01f429667104c0c5a5f321700f15435c.jpg',
#  'train/0206c12e8984e3c8a166cc272de25d6f.jpg',
#  'train/023e4e28415506e0deddcbd8f8bdab29.jpg',
#  'train/02508e76981e1ba059d785704b4c480c.jpg']

# %%
labels_csv["breed"].value_counts().plot.bar(figsize=(20,10));

# %%
Image(filenames[10])

# %%
labels=np.array(labels_csv["breed"])
len(labels),labels
# Out:
# (841,
#  array(['golden_retriever', 'scottish_deerhound', 'doberman',
#         'golden_retriever', 'golden_retriever', 'scottish_deerhound',
#         'malamute', 'chihuahua', 'pug', 'pug', 'golden_retriever',
#         'saint_bernard', 'saint_bernard', 'scottish_deerhound', 'malamute',
#         'doberman', 'doberman', 'beagle', 'scottish_deerhound',
#         'scottish_deerhound', 'scottish_deerhound', 'pug', 'doberman',
#         'doberman', 'pug', 'golden_retriever', 'scottish_deerhound',
#         'chihuahua', 'french_bulldog', 'saint_bernard', 'malamute',
#         'french_bulldog', 'tibetan_mastiff', 'tibetan_mastiff', 'malamute',
#         'scottish_deerhound', 'beagle', 'scottish_deerhound', 'malamute',
#         'golden_retriever', 'pug', 'doberman', 'beagle', 'tibetan_mastiff',
#         'scottish_deerhound', 'malamute', 'beagle', 'beagle', 'chihuahua',
#         'chihuahua', 'pug', 'scottish_deerhound', 'pug', 'malamute', 'pug',
#         'beagle', 'french_bulldog', 'scottish_deerhound',
#         'scottish_deerhound', 'malamute', 'doberman', 'beagle', 'doberman',
#         'chihuahua', 'malamute', 'tibetan_mastiff', 'saint_bernard',
#         'chihuahua', 'pug', 'beagle', 'saint_bernard', 'chihuahua',
#         'scottish_deerhound', 'doberman', 'malamute', 'malamute',
#         'golden_retriever', 'golden_retriever', 'chihuahua', 'malamute',
#         'tibetan_mastiff', 'scottish_deerhound', 'pug', 'malamute',
#         'scottish_deerhound', 'pug', 'malamute', 'malamute', 'chihuahua',
#         'saint_bernard', 'pug', 'tibetan_mastiff', 'pug',
#         'tibetan_mastiff', 'malamute', 'golden_retriever', 'beagle',
#         'golden_retriever', 'beagle', 'scottish_deerhound',
#         'tibetan_mastiff', 'beagle', 'pug', 'french_bulldog',
#         'golden_retriever', 'chihuahua', 'french_bulldog', 'malamute',
#         'chihuahua', 'beagle', 'pug', 'golden_retriever', 'saint_bernard',
#         'tibetan_mastiff', 'pug', 'scottish_deerhound', 'pug', 'pug',
#         'french_bulldog', 'golden_retriever', 'scottish_deerhound',
#         'malamute', 'pug', 'beagle', 'chihuahua', 'pug', 'chihuahua',
#         'french_bulldog', 'scottish_deerhound', 'pug', 'tibetan_mastiff',
#         'doberman', 'french_bulldog', 'saint_bernard', 'tibetan_mastiff',
#         'scottish_deerhound', 'french_bulldog', 'doberman', 'chihuahua',
#         'golden_retriever', 'beagle', 'tibetan_mastiff', 'saint_bernard',
#         'french_bulldog', 'malamute', 'beagle', 'scottish_deerhound',
#         'french_bulldog', 'tibetan_mastiff', 'french_bulldog',
#         'golden_retriever', 'malamute', 'pug', 'tibetan_mastiff',
#         'scottish_deerhound', 'saint_bernard', 'beagle', 'chihuahua',
#         'tibetan_mastiff', 'golden_retriever', 'chihuahua', 'chihuahua',
#         'beagle', 'saint_bernard', 'french_bulldog', 'chihuahua', 'beagle',
#         'saint_bernard', 'pug', 'saint_bernard', 'malamute', 'malamute',
#         'malamute', 'beagle', 'tibetan_mastiff', 'chihuahua',
#         'saint_bernard', 'malamute', 'doberman', 'scottish_deerhound',
#         'saint_bernard', 'pug', 'beagle', 'french_bulldog', 'doberman',
#         'french_bulldog', 'beagle', 'scottish_deerhound',
#         'scottish_deerhound', 'french_bulldog', 'doberman',
#         'french_bulldog', 'golden_retriever', 'tibetan_mastiff',
#         'saint_bernard', 'golden_retriever', 'malamute',
#         'scottish_deerhound', 'scottish_deerhound', 'scottish_deerhound',
#         'malamute', 'saint_bernard', 'french_bulldog', 'pug',
#         'tibetan_mastiff', 'french_bulldog', 'tibetan_mastiff',
#         'saint_bernard', 'scottish_deerhound', 'malamute', 'doberman',
#         'beagle', 'pug', 'scottish_deerhound', 'scottish_deerhound', 'pug',
#         'saint_bernard', 'scottish_deerhound', 'scottish_deerhound',
#         'golden_retriever', 'doberman', 'saint_bernard',
#         'scottish_deerhound', 'beagle', 'golden_retriever', 'pug',
#         'chihuahua', 'beagle', 'tibetan_mastiff', 'beagle', 'pug',
#         'malamute', 'saint_bernard', 'tibetan_mastiff',
#         'scottish_deerhound', 'scottish_deerhound', 'beagle', 'doberman',
#         'scottish_deerhound', 'beagle', 'beagle', 'beagle', 'malamute',
#         'saint_bernard', 'tibetan_mastiff', 'french_bulldog',
#         'saint_bernard', 'golden_retriever', 'pug', 'chihuahua',
#         'saint_bernard', 'beagle', 'chihuahua', 'doberman', 'doberman',
#         'pug', 'french_bulldog', 'pug', 'pug', 'malamute', 'beagle',
#         'malamute', 'french_bulldog', 'malamute', 'scottish_deerhound',
#         'doberman', 'pug', 'beagle', 'doberman', 'doberman', 'pug',
#         'doberman', 'tibetan_mastiff', 'malamute', 'scottish_deerhound',
#         'chihuahua', 'malamute', 'beagle', 'chihuahua', 'tibetan_mastiff',
#         'saint_bernard', 'golden_retriever', 'chihuahua', 'malamute',
#         'tibetan_mastiff', 'pug', 'doberman', 'pug', 'golden_retriever',
#         'chihuahua', 'beagle', 'malamute', 'pug', 'french_bulldog',
#         'golden_retriever', 'chihuahua', 'scottish_deerhound', 'doberman',
#         'golden_retriever', 'french_bulldog', 'pug', 'french_bulldog',
#         'chihuahua', 'beagle', 'beagle', 'saint_bernard', 'chihuahua',
#         'golden_retriever', 'french_bulldog', 'beagle',
#         'scottish_deerhound', 'chihuahua', 'saint_bernard', 'malamute',
#         'golden_retriever', 'saint_bernard', 'golden_retriever', 'beagle',
#         'scottish_deerhound', 'doberman', 'saint_bernard',
#         'tibetan_mastiff', 'french_bulldog', 'chihuahua', 'saint_bernard',
#         'beagle', 'pug', 'saint_bernard', 'pug', 'pug', 'golden_retriever',
#         'scottish_deerhound', 'scottish_deerhound', 'beagle', 'chihuahua',
#         'scottish_deerhound', 'saint_bernard', 'french_bulldog', 'beagle',
#         'chihuahua', 'tibetan_mastiff', 'beagle', 'tibetan_mastiff',
#         'scottish_deerhound', 'saint_bernard', 'tibetan_mastiff',
#         'chihuahua', 'chihuahua', 'beagle', 'golden_retriever',
#         'scottish_deerhound', 'scottish_deerhound', 'malamute', 'pug',
#         'beagle', 'saint_bernard', 'tibetan_mastiff', 'doberman', 'beagle',
#         'malamute', 'french_bulldog', 'doberman', 'chihuahua', 'beagle',
#         'doberman', 'golden_retriever', 'golden_retriever',
#         'saint_bernard', 'golden_retriever', 'beagle', 'doberman',
#         'tibetan_mastiff', 'saint_bernard', 'pug', 'scottish_deerhound',
#         'chihuahua', 'malamute', 'french_bulldog', 'chihuahua',
#         'golden_retriever', 'doberman', 'beagle', 'beagle', 'beagle',
#         'beagle', 'tibetan_mastiff', 'pug', 'scottish_deerhound',
#         'french_bulldog', 'french_bulldog', 'pug', 'malamute', 'pug',
#         'scottish_deerhound', 'saint_bernard', 'doberman', 'malamute',
#         'scottish_deerhound', 'french_bulldog', 'tibetan_mastiff',
#         'scottish_deerhound', 'saint_bernard', 'scottish_deerhound',
#         'scottish_deerhound', 'chihuahua', 'saint_bernard',
#         'scottish_deerhound', 'beagle', 'malamute', 'pug', 'pug',
#         'tibetan_mastiff', 'pug', 'pug', 'scottish_deerhound',
#         'scottish_deerhound', 'french_bulldog', 'doberman',
#         'scottish_deerhound', 'tibetan_mastiff', 'saint_bernard',
#         'saint_bernard', 'doberman', 'golden_retriever',
#         'scottish_deerhound', 'chihuahua', 'golden_retriever', 'doberman',
#         'golden_retriever', 'malamute', 'scottish_deerhound', 'chihuahua',
#         'scottish_deerhound', 'scottish_deerhound', 'pug', 'saint_bernard',
#         'beagle', 'tibetan_mastiff', 'scottish_deerhound', 'malamute',
#         'doberman', 'scottish_deerhound', 'saint_bernard',
#         'scottish_deerhound', 'malamute', 'beagle', 'golden_retriever',
#         'saint_bernard', 'beagle', 'scottish_deerhound', 'tibetan_mastiff',
#         'beagle', 'beagle', 'scottish_deerhound', 'saint_bernard',
#         'doberman', 'scottish_deerhound', 'malamute', 'pug',
#         'french_bulldog', 'scottish_deerhound', 'scottish_deerhound',
#         'saint_bernard', 'golden_retriever', 'scottish_deerhound',
#         'doberman', 'scottish_deerhound', 'saint_bernard',
#         'golden_retriever', 'beagle', 'pug', 'malamute', 'beagle',
#         'doberman', 'chihuahua', 'scottish_deerhound', 'chihuahua',
#         'beagle', 'golden_retriever', 'malamute', 'pug', 'tibetan_mastiff',
#         'beagle', 'malamute', 'tibetan_mastiff', 'saint_bernard', 'beagle',
#         'beagle', 'malamute', 'beagle', 'beagle', 'saint_bernard',
#         'beagle', 'doberman', 'french_bulldog', 'tibetan_mastiff',
#         'saint_bernard', 'saint_bernard', 'scottish_deerhound', 'pug',
#         'malamute', 'tibetan_mastiff', 'french_bulldog', 'saint_bernard',
#         'golden_retriever', 'scottish_deerhound', 'pug', 'pug', 'doberman',
#         'tibetan_mastiff', 'pug', 'french_bulldog', 'scottish_deerhound',
#         'beagle', 'malamute', 'tibetan_mastiff', 'doberman',
#         'scottish_deerhound', 'chihuahua', 'tibetan_mastiff',
#         'scottish_deerhound', 'scottish_deerhound', 'malamute',
#         'golden_retriever', 'doberman', 'malamute', 'beagle', 'doberman',
#         'pug', 'chihuahua', 'golden_retriever', 'doberman', 'malamute',
#         'tibetan_mastiff', 'doberman', 'french_bulldog', 'french_bulldog',
#         'tibetan_mastiff', 'pug', 'beagle', 'pug', 'scottish_deerhound',
#         'scottish_deerhound', 'french_bulldog', 'scottish_deerhound',
#         'doberman', 'beagle', 'saint_bernard', 'scottish_deerhound',
#         'malamute', 'french_bulldog', 'malamute', 'french_bulldog',
#         'golden_retriever', 'pug', 'beagle', 'malamute', 'chihuahua',
#         'doberman', 'scottish_deerhound', 'doberman', 'doberman',
#         'malamute', 'saint_bernard', 'malamute', 'malamute',
#         'scottish_deerhound', 'saint_bernard', 'pug', 'scottish_deerhound',
#         'malamute', 'french_bulldog', 'pug', 'chihuahua', 'malamute',
#         'french_bulldog', 'french_bulldog', 'chihuahua', 'saint_bernard',
#         'beagle', 'scottish_deerhound', 'saint_bernard', 'beagle',
#         'doberman', 'golden_retriever', 'scottish_deerhound', 'chihuahua',
#         'chihuahua', 'golden_retriever', 'chihuahua', 'saint_bernard',
#         'saint_bernard', 'pug', 'saint_bernard', 'scottish_deerhound',
#         'pug', 'golden_retriever', 'saint_bernard', 'golden_retriever',
#         'malamute', 'chihuahua', 'tibetan_mastiff', 'doberman', 'beagle',
#         'scottish_deerhound', 'chihuahua', 'doberman', 'saint_bernard',
#         'golden_retriever', 'beagle', 'doberman', 'malamute', 'pug',
#         'saint_bernard', 'french_bulldog', 'french_bulldog',
#         'golden_retriever', 'scottish_deerhound', 'chihuahua', 'malamute',
#         'tibetan_mastiff', 'doberman', 'chihuahua', 'doberman', 'doberman',
#         'scottish_deerhound', 'french_bulldog', 'doberman',
#         'french_bulldog', 'beagle', 'scottish_deerhound', 'beagle',
#         'malamute', 'pug', 'scottish_deerhound', 'chihuahua',
#         'golden_retriever', 'chihuahua', 'scottish_deerhound',
#         'french_bulldog', 'pug', 'pug', 'tibetan_mastiff',
#         'scottish_deerhound', 'golden_retriever', 'scottish_deerhound',
#         'french_bulldog', 'doberman', 'beagle', 'tibetan_mastiff',
#         'tibetan_mastiff', 'scottish_deerhound', 'beagle', 'doberman',
#         'pug', 'malamute', 'doberman', 'saint_bernard', 'saint_bernard',
#         'malamute', 'doberman', 'beagle', 'doberman', 'scottish_deerhound',
#         'tibetan_mastiff', 'beagle', 'scottish_deerhound',
#         'french_bulldog', 'tibetan_mastiff', 'saint_bernard', 'beagle',
#         'beagle', 'french_bulldog', 'malamute', 'french_bulldog',
#         'scottish_deerhound', 'scottish_deerhound', 'scottish_deerhound',
#         'pug', 'saint_bernard', 'saint_bernard', 'tibetan_mastiff', 'pug',
#         'tibetan_mastiff', 'chihuahua', 'malamute', 'pug', 'beagle', 'pug',
#         'saint_bernard', 'saint_bernard', 'scottish_deerhound', 'malamute',
#         'golden_retriever', 'malamute', 'scottish_deerhound',
#         'scottish_deerhound', 'scottish_deerhound', 'golden_retriever',
#         'chihuahua', 'chihuahua', 'saint_bernard', 'french_bulldog',
#         'french_bulldog', 'chihuahua', 'scottish_deerhound', 'pug',
#         'tibetan_mastiff', 'malamute', 'golden_retriever',
#         'golden_retriever', 'beagle', 'beagle', 'chihuahua',
#         'golden_retriever', 'french_bulldog', 'tibetan_mastiff',
#         'scottish_deerhound', 'beagle', 'beagle', 'beagle',
#         'scottish_deerhound', 'tibetan_mastiff', 'doberman',
#         'french_bulldog', 'saint_bernard', 'chihuahua', 'tibetan_mastiff',
#         'beagle', 'beagle', 'golden_retriever', 'beagle',
#         'golden_retriever', 'chihuahua', 'chihuahua', 'french_bulldog',
#         'malamute', 'tibetan_mastiff', 'pug', 'tibetan_mastiff',
#         'scottish_deerhound', 'tibetan_mastiff', 'doberman', 'pug',
#         'beagle', 'french_bulldog', 'pug', 'beagle', 'doberman',
#         'golden_retriever', 'doberman', 'saint_bernard', 'saint_bernard',
#         'pug', 'scottish_deerhound', 'beagle', 'beagle', 'beagle',
#         'malamute', 'tibetan_mastiff', 'saint_bernard', 'chihuahua',
#         'saint_bernard', 'saint_bernard', 'chihuahua', 'beagle',
#         'tibetan_mastiff', 'doberman', 'saint_bernard', 'doberman', 'pug',
#         'pug', 'malamute', 'scottish_deerhound', 'scottish_deerhound',
#         'pug', 'french_bulldog', 'doberman', 'saint_bernard',
#         'french_bulldog', 'doberman', 'malamute', 'doberman',
#         'scottish_deerhound', 'scottish_deerhound', 'scottish_deerhound',
#         'golden_retriever', 'beagle', 'french_bulldog', 'chihuahua',
#         'saint_bernard', 'golden_retriever', 'beagle', 'beagle',
#         'french_bulldog', 'beagle', 'golden_retriever', 'french_bulldog',
#         'scottish_deerhound', 'scottish_deerhound', 'scottish_deerhound',
#         'french_bulldog', 'malamute', 'tibetan_mastiff', 'chihuahua',
#         'pug', 'beagle', 'chihuahua', 'french_bulldog',
#         'scottish_deerhound', 'french_bulldog', 'pug', 'pug', 'pug', 'pug',
#         'golden_retriever', 'saint_bernard', 'pug', 'malamute',
#         'scottish_deerhound', 'scottish_deerhound', 'doberman', 'beagle',
#         'tibetan_mastiff', 'pug', 'pug', 'beagle', 'saint_bernard',
#         'saint_bernard', 'tibetan_mastiff', 'chihuahua', 'tibetan_mastiff',
#         'doberman', 'saint_bernard', 'french_bulldog', 'pug',
#         'scottish_deerhound', 'tibetan_mastiff', 'pug', 'golden_retriever',
#         'golden_retriever'], dtype=object))

# %%
# Turn labels into boolean labels
boolean_labels=[label==np.array(labels_using) for label in labels]
boolean_labels[:2]
# Out:
# [array([False, False, False, False,  True, False, False, False, False,
#         False]),
#  array([False, False, False, False, False, False, False, False,  True,
#         False])]

# %% [markdown]
# ## Creating training and validation set

# %%
x=filenames
y=boolean_labels

# %%
from matplotlib.pyplot import imread
image=imread(filenames[100])
image.shape
# Out:
# (382, 500, 3)

# %% [markdown]
# ## Preprocessing Image

# %%
# Define image size
IMG_SIZE=224
 
# Create a function for preprocessing images
def process_image(image_path,img_size=IMG_SIZE):
    # Read in an image file
    image=tf.io.read_file(image_path)
    # Turn jpeg into numerical tensor with 3 colour channel(R,G,B)
    image=tf.image.decode_jpeg(image,channels=3)
    # Convert color channels value from 0-255 to 0-1 values
    image=tf.image.convert_image_dtype(image,tf.float32)
    # Resize the image to our desired value
    image=tf.image.resize(image,size=[IMG_SIZE,IMG_SIZE])

    return image

# %%
# Create a simple function to return a tuple(image,label)
def get_image_label(image_path,label):
    image=process_image(image_path)
    return image,label

# %% [markdown]
# ## Convert data into batches

# %%
BATCH_SIZE =32
# Create a function to turn data into batches
def create_data_batches(x, y=None, batch_size=BATCH_SIZE, valid_data=False, test_data=False):
    if test_data:
        print("Creating test data batches...")
        data=tf.data.Dataset.from_tensor_slices(tf.constant(x)) # only filepath no label
        data_batch=data.map(process_image).batch(BATCH_SIZE)
        return data_batch
    
    elif valid_data:
        print("Creating valid data batches...")
        # Turn filepath and label into tensors
        data=tf.data.Dataset.from_tensor_slices((tf.constant(x),  
                                             tf.constant(y))) 
        data_batch=data.map(get_image_label).batch(BATCH_SIZE)
        return data_batch
  
    else:
        print("Creating training data batches...")
        data=tf.data.Dataset.from_tensor_slices((tf.constant(x),
                                             tf.constant(y)))
        # Shuffling the pathnames and labels  
        data=data.shuffle(buffer_size=len(x))
        data=data.map(get_image_label)
        data_batch=data.batch(BATCH_SIZE)
    return data_batch

# %%
# Create training and validation data batches
train_data=create_data_batches(x,y)
# Out:
# Creating training data batches...

# %%
# Create a function for viewing images in data batch
def show_25_images(images,labels):
    plt.figure(figsize=(10,10))
    for i in range(25):
        ax=plt.subplot(5, 5, i+1)
        plt.imshow(images[i])
        plt.title(labels_using[labels[i].argmax()])
        plt.axis("off")

# %%
train_images,train_labels=next(train_data.as_numpy_iterator())

# %%
train_images,train_labels
# Out:
# (array([[[[4.80818152e-02, 7.50087574e-02, 9.80141312e-02],
#           [6.27030879e-02, 7.44992942e-02, 9.41123813e-02],
#           [6.79592565e-02, 6.40814602e-02, 8.36893022e-02],
#           ...,
#           [6.25638962e-01, 6.70054317e-01, 5.74615002e-01],
#           [6.20378196e-01, 6.59593880e-01, 5.61554670e-01],
#           [6.07843876e-01, 6.47059560e-01, 5.49020350e-01]],
#
#           [2.77197093e-01, 3.36020619e-01, 3.48950148e-01]],
#
#          [[8.51547599e-01, 9.11456525e-01, 9.47591007e-01],
#           [8.79247069e-01, 9.39156055e-01, 9.73449111e-01],
#           [8.87585402e-01, 9.47494328e-01, 9.83628809e-01],
#           ...,
#           [1.80164114e-01, 2.50752360e-01, 3.05024117e-01],
#           [1.91895261e-01, 2.58662909e-01, 2.86568940e-01],
#           [2.33911887e-01, 2.99496591e-01, 3.20676476e-01]],
#
#          [[5.34895897e-01, 5.93824446e-01, 5.86267352e-01],
#           [5.15688837e-01, 5.76438129e-01, 5.68157613e-01],
#           [5.43779075e-01, 6.05088592e-01, 5.96585512e-01],
#           ...,
#           [1.48437232e-01, 2.17414826e-01, 2.71010667e-01],
#           [1.96585029e-01, 2.64179260e-01, 2.96322703e-01],
#           [1.67448282e-01, 2.35229477e-01, 2.66088635e-01]],
#
#          ...,
#
#          [[6.60257101e-01, 6.40649259e-01, 4.90018815e-01],
#           [5.85696459e-01, 5.70815623e-01, 4.19379771e-01],
#           [6.33395374e-01, 6.26497626e-01, 4.71630484e-01],
#           ...,
#           [5.12073457e-01, 5.49427927e-01, 3.15819800e-01],
#           [5.66199720e-01, 6.02439880e-01, 3.86525124e-01],
#           [4.37454045e-01, 4.78980452e-01, 2.61788875e-01]],
#
#          [[6.64322019e-01, 6.48884118e-01, 5.00281215e-01],
#           [5.58769047e-01, 5.51906168e-01, 4.00480837e-01],
#           [6.46115482e-01, 6.48951709e-01, 4.94259685e-01],
#           ...,
#           [5.26251853e-01, 5.71559787e-01, 3.46279472e-01],
#           [6.22175276e-01, 6.64983034e-01, 4.45869446e-01],
#           [4.32073802e-01, 4.73040372e-01, 2.56688535e-01]],
#
#          [[5.34408510e-01, 5.25839388e-01, 3.77182722e-01],
#           [4.74377692e-01, 4.74090695e-01, 3.25071067e-01],
#           [6.78209662e-01, 6.78687930e-01, 5.29429197e-01],
#           ...,
#           [5.59212089e-01, 6.10670745e-01, 3.90823781e-01],
#           [4.94554609e-01, 5.31452596e-01, 3.21203649e-01],
#           [4.29621637e-01, 4.64915752e-01, 2.57072598e-01]]]],
#        dtype=float32),
#  array([[False, False, False, False, False, False, False, False,  True,
#          False],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [False, False, False, False, False, False, False,  True, False,
#          False],
#         [False,  True, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False, False,  True, False,
#          False],
#         [False, False, False, False, False, False, False, False, False,
#           True],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False, False, False, False,
#           True],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [False, False, False, False, False,  True, False, False, False,
#          False],
#         [False, False, False, False, False,  True, False, False, False,
#          False],
#         [False, False, False, False, False, False, False,  True, False,
#          False],
#         [False, False, False, False, False, False, False, False,  True,
#          False],
#         [False, False, False, False, False, False, False,  True, False,
#          False],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [False, False, False,  True, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False, False, False,  True,
#          False],
#         [False, False, False,  True, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [False, False, False, False, False, False, False, False,  True,
#          False],
#         [False, False, False, False, False,  True, False, False, False,
#          False],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False, False,  True, False,
#          False],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False, False, False,  True, False, False, False, False, False,
#          False],
#         [False, False, False, False, False, False,  True, False, False,
#          False],
#         [ True, False, False, False, False, False, False, False, False,
#          False],
#         [False,  True, False, False, False, False, False, False, False,
#          False],
#         [False, False, False, False, False,  True, False, False, False,
#          False]]))

# %%
show_25_images(train_images,train_labels)

# %% [markdown]
# ## Model building

# %%
# Setup input shape to the model
INPUT_SHAPE=[None, IMG_SIZE, IMG_SIZE, 3] # batch, height, width, colour channels 
# Setup output shape of our model
OUTPUT_SHAPE=len(labels_using)
# Setup model url from Tensorflow Hub
MODEL_URL="https://tfhub.dev/google/imagenet/resnet_v2_50/classification/5"

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred): 
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Create a function which build keras model
def create_model(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, model_url=MODEL_URL):
    print("Building model with", MODEL_URL)

    # Setup model layers
    model=tf.keras.Sequential([
        hub.KerasLayer(MODEL_URL),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(2048, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=OUTPUT_SHAPE,
        activation="softmax") 

  ])

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(),
        optimizer=tf.keras.optimizers.Adam(),
        metrics=["accuracy",f1_score]
  )

    # Build the model
    model.build(INPUT_SHAPE)

    return model

# %%
model=create_model()
model.summary()
# Out:
# Building model with https://tfhub.dev/google/imagenet/resnet_v2_50/classification/5
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000020EBF799BB0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000020EBF799BB0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000020EBF799BB0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              25615849
# _________________________________________________________________
# flatten (Flatten)            (None, 1001)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              2052096
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 28,209,587
# Trainable params: 2,593,738
# Non-trainable params: 25,615,849
# _________________________________________________________________

# %%
# Creating early stopping
early_stopping=tf.keras.callbacks.EarlyStopping(monitor="accuracy",
                                                patience=3)

# %%
model.fit(x=train_data,
            epochs=10,
            callbacks=[ early_stopping])
# Out:
# Epoch 1/10
# 27/27 [==============================] - 91s 3s/step - loss: 1.4594 - accuracy: 0.5945 - f1_score: 0.5865
# Epoch 2/10
# 27/27 [==============================] - 93s 3s/step - loss: 0.6371 - accuracy: 0.8383 - f1_score: 0.8409
# Epoch 3/10
# 27/27 [==============================] - 89s 3s/step - loss: 0.5024 - accuracy: 0.8597 - f1_score: 0.8644
# Epoch 4/10
# 27/27 [==============================] - 86s 3s/step - loss: 0.3741 - accuracy: 0.8966 - f1_score: 0.9023
# Epoch 5/10
# 27/27 [==============================] - 84s 3s/step - loss: 0.3423 - accuracy: 0.9049 - f1_score: 0.9093
# Epoch 6/10
# 27/27 [==============================] - 83s 3s/step - loss: 0.1989 - accuracy: 0.9298 - f1_score: 0.9322
# Epoch 7/10
# 27/27 [==============================] - 87s 3s/step - loss: 0.2309 - accuracy: 0.9417 - f1_score: 0.9441
# Epoch 8/10
# 27/27 [==============================] - 84s 3s/step - loss: 0.2464 - accuracy: 0.9405 - f1_score: 0.9403
# Epoch 9/10
# 27/27 [==============================] - 84s 3s/step - loss: 0.2465 - accuracy: 0.9322 - f1_score: 0.9357
# Epoch 10/10
# 27/27 [==============================] - 84s 3s/step - loss: 0.1536 - accuracy: 0.9608 - f1_score: 0.9638

# %%
test_path="test/"
test_filenames=[test_path + fnames for fnames in os.listdir(test_path)]
test_filenames[:10]
# Out:
# ['test/000621fb3cbb32d8935728e48679680e.jpg',
#  'test/00102ee9d8eb90812350685311fe5890.jpg',
#  'test/0012a730dfa437f5f3613fb75efcd4ce.jpg',
#  'test/001510bc8570bbeee98c8d80c8a95ec1.jpg',
#  'test/001a5f3114548acdefa3d4da05474c2e.jpg',
#  'test/00225dcd3e4d2410dd53239f95c0352f.jpg',
#  'test/002c2a3117c2193b4d26400ce431eebd.jpg',
#  'test/002c58d413a521ae8d1a5daeb35fc803.jpg',
#  'test/002f80396f1e3db687c5932d7978b196.jpg',
#  'test/0036c6bcec6031be9e62a257b1c3c442.jpg']

# %%
# Create test data batch
test_data=create_data_batches(test_filenames, test_data=True)
# Out:
# Creating test data batches...

# %%
test_prediction= model.predict(test_data, 
                              verbose=1)
# Out:
# 324/324 [==============================] - 1156s 4s/step

# %%
model.save("DogClassification_resnet_v2_50")
# Out:
# WARNING:tensorflow:From C:\Users\prabhanshu\anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\prabhanshu\anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\prabhanshu\anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\prabhanshu\anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: DogClassification_resnet_v2_50\assets
# INFO:tensorflow:Assets written to: DogClassification_resnet_v2_50\assets

# %%
np.savetxt('preds_array.csv', test_prediction, delimiter=",")

# %%
test_prediction.shape
# Out:
# (10357, 10)

# %%
preds_df=pd.DataFrame(columns=["id"] +list(labels_using))
test_ids=[os.path.splitext(path)[0] for path in os.listdir(test_path)]
preds_df["id"]= test_ids
preds_df[list(labels_using)]=test_prediction
preds_df.head()
# Out:
#                                  id    beagle chihuahua  doberman  \
# 0  000621fb3cbb32d8935728e48679680e  0.017518  0.003878  0.080671
# 1  00102ee9d8eb90812350685311fe5890  0.000003  0.000001  0.000001
# 2  0012a730dfa437f5f3613fb75efcd4ce       0.0       0.0       0.0
# 3  001510bc8570bbeee98c8d80c8a95ec1  0.001993  0.000146  0.004311
# 4  001a5f3114548acdefa3d4da05474c2e       0.0       0.0  0.000008
#
#   french_bulldog golden_retriever  malamute       pug saint_bernard  \
# 0       0.029444         0.001469  0.021205  0.014014      0.184327
# 1       0.000002         0.000005  0.987939       0.0      0.000001
# 2            0.0              0.0       0.0  0.000002           0.0
# 3       0.039774         0.000656  0.156715  0.623486      0.002222
# 4       0.000331              0.0  0.006942  0.033968      0.000054
#
#   scottish_deerhound tibetan_mastiff
# 0           0.031566        0.615908
# 1           0.000012        0.012037
# 2           0.999998             0.0
# 3           0.000655        0.170043
# 4           0.000012        0.958685

# %% [markdown]
# # Loss,accuracy,F1_score,Confusion_matrix,roc-auc curve for test data
#
# * We can not evaluate test data because we dont have actual labels to compare with our predicted labels
# so instead of evaluating on test_data i m evaluating on valid data but for demo I m evaluating on test data which gona show `Null`

# %%
## Demo
# Loss,accuracy,F1_score for test data 
loss,accuracy,f1_score=model.evaluate(test_data)
print("Loss: ",loss)
print("Accuracy: ",accuracy)
print("F1_score: ",f1_score)
# Out:
# 324/324 [==============================] - 54s 166ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - f1_score: 0.0000e+00
# Loss:  0.0
# Accuracy:  0.0
# F1_score:  0.0

# %%
# Now evaluating on valid data
x_val,y_val=x[671:841],y[671:841]
val_data=create_data_batches(x_val,y_val,valid_data=True )
# Out:
# Creating valid data batches...

# %%
# Loss,accuracy,F1_score for valid data 
loss,accuracy,f1_score=model.evaluate(val_data)
print("Loss: ",loss)
print("Accuracy: ",accuracy)
print("F1_score: ",f1_score)
# Out:
# 6/6 [==============================] - 15s 3s/step - loss: 0.0137 - accuracy: 0.9941 - f1_score: 0.9948
# Loss:  0.013662402518093586
# Accuracy:  0.9941176176071167
# F1_score:  0.9947916865348816
